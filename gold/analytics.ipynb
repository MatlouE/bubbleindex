# %%
import pandas as pd
import numpy as np

# %%
fundamentals = pd.read_csv('/workspaces/bubbleindex/silver/combined_fundamentals.csv')
prices = pd.read_csv('/workspaces/bubbleindex/silver/combined_stockprices.csv')

# %%
prices.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7393 entries, 0 to 7392
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         7393 non-null   str
#  1   ticker       7393 non-null   str
#  2   close_price  7393 non-null   float64
#  3   Volume       7393 non-null   int64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 231.2 KB

# %%
fundamentals['Date'] = pd.to_datetime(fundamentals['Date'])
prices['Date'] = pd.to_datetime(prices['Date'], utc='True')

# %%
fundamentals.info()
prices.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ticker                    20 non-null     str
#  1   Date                      20 non-null     datetime64[us]
#  2   Free Cash Flow            20 non-null     float64
#  3   Beginning Cash Position   20 non-null     float64
#  4   End Cash Position         20 non-null     float64
#  5   Total Revenue             20 non-null     float64
#  6   Gross Profit              20 non-null     float64
#  7   Net Income                20 non-null     float64
#  8   Diluted EPS               19 non-null     float64
#  9   Research And Development  20 non-null     float64
#  10  EBITDA                    20 non-null     float64
#  11  Tax Provision             20 non-null     float64
#  12  Total Debt                20 non-null     float64
#  13  Working Capital           20 non-null     float64
#  14  Gross Margin              20 non-null     float64
#  15  Net Margin                20 non-null     float64
#  16  FCF Margin                20 non-null     float64
#  17  Debt to Equity            20 non-null     float64
#  18  Working Capital Ratio     20 non-null     float64
#  19  R&D to Revenue            20 non-null     float64
#  20  Revenue growth            15 non-null     float64
#  21  Net Income Growth         15 non-null     float64
#  22  EPS Growth                14 non-null     float64
#  23  FCF Growth                15 non-null     float64
# dtypes: datetime64[us](1), float64(22), str(1)
# memory usage: 3.9 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 7393 entries, 0 to 7392
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         7393 non-null   datetime64[us, UTC]
#  1   ticker       7393 non-null   str
#  2   close_price  7393 non-null   float64
#  3   Volume       7393 non-null   int64
# dtypes: datetime64[us, UTC](1), float64(1), int64(1), str(1)
# memory usage: 231.2 KB

# %% [markdown]
# Fundamentals Analysis

# %%
#get latest fundamentals & prices for each company
latest_fundamentals = fundamentals.sort_values('Date').groupby('ticker').tail(1).reset_index(drop=True)
latest_prices = prices.sort_values('Date').groupby('ticker').tail(1).reset_index(drop=True)

# %%
latest_fundamentals.head()
# Out:
#   ticker       Date  Free Cash Flow  Beginning Cash Position  \
# 0   MSFT 2025-06-30    7.161100e+10             1.831500e+10
# 1   META 2025-12-31    4.610900e+10             4.543800e+10
# 2  GOOGL 2025-12-31    7.326600e+10             2.346600e+10
# 3   PLTR 2025-12-31    2.100591e+09             2.119936e+09
# 4   NVDA 2026-01-31    9.667600e+10             8.589000e+09
#
#    End Cash Position  Total Revenue  Gross Profit    Net Income  Diluted EPS  \
# 0       3.024200e+10   2.817240e+11  1.938930e+11  1.018320e+11        13.64
# 1       3.910000e+10   2.009660e+11  1.647910e+11  6.045800e+10          NaN
# 2       3.070800e+10   4.028360e+11  2.403010e+11  1.321700e+11        10.81
# 3       1.451425e+09   4.475446e+09  3.686269e+09  1.625033e+09         0.63
# 4       1.060500e+10   2.159380e+11  1.534630e+11  1.200670e+11         4.90
#
#    Research And Development  ...  Gross Margin  Net Margin  FCF Margin  \
# 0              3.248800e+10  ...      0.688237    0.361460    0.254188
# 1              5.737200e+10  ...      0.819994    0.300837    0.229437
# 2              6.108700e+10  ...      0.596523    0.328099    0.181876
# 3              5.576770e+08  ...      0.823665    0.363100    0.469359
# 4              1.849700e+10  ...      0.710681    0.556025    0.447703
#
#    Debt to Equity  Working Capital Ratio  R&D to Revenue  Revenue growth  \
# 0        0.548303               0.177170        0.115319        0.149322
# 1        0.556409               0.332822        0.285481        0.221670
# 2        0.364679               0.256415        0.151642        0.150901
# 3        0.030942               1.604889        0.124608        0.561834
# 4        0.105664               0.432726        0.085659        0.654735
#
#    Net Income Growth  EPS Growth  FCF Growth
# 0           0.155396    0.155932   -0.033211
# 1          -0.030500         NaN   -0.147267
# 2           0.320142    0.344527    0.006899
# 3           2.515941    2.310962    0.840636
# 4           0.647462    0.666667    0.588681
#
# [5 rows x 24 columns]

# %%
fund_trends = fundamentals.sort_values(['ticker', 'Date']).copy()

# %%
fund_trends
# Out:
#    ticker       Date  Free Cash Flow  Beginning Cash Position  \
# 0   GOOGL 2022-12-31    6.001000e+10             2.094500e+10
# 1   GOOGL 2023-12-31    6.949500e+10             2.187900e+10
# 2   GOOGL 2024-12-31    7.276400e+10             2.404800e+10
# 3   GOOGL 2025-12-31    7.326600e+10             2.346600e+10
# 4    META 2022-12-31    1.928900e+10             1.686500e+10
# 5    META 2023-12-31    4.406800e+10             1.559600e+10
# 6    META 2024-12-31    5.407200e+10             4.282700e+10
# 7    META 2025-12-31    4.610900e+10             4.543800e+10
# 8    MSFT 2022-06-30    6.514900e+10             1.422400e+10
# 9    MSFT 2023-06-30    5.947500e+10             1.393100e+10
# 10   MSFT 2024-06-30    7.407100e+10             3.470400e+10
# 11   MSFT 2025-06-30    7.161100e+10             1.831500e+10
# 12   NVDA 2023-01-31    3.808000e+09             1.990000e+09
# 13   NVDA 2024-01-31    2.702100e+10             3.389000e+09
# 14   NVDA 2025-01-31    6.085300e+10             7.280000e+09
# 15   NVDA 2026-01-31    9.667600e+10             8.589000e+09
# 16   PLTR 2022-12-31    1.837100e+08             2.366914e+09
# 17   PLTR 2023-12-31    6.970690e+08             2.627335e+09
# 18   PLTR 2024-12-31    1.141231e+09             8.501070e+08
# 15              1.849700e+10  ...      0.710681    0.556025    0.447703
# 16              3.596790e+08  ...      0.785637   -0.196081    0.096392
# 17              4.046240e+08  ...      0.806246    0.094303    0.313288
# 18              5.078780e+08  ...      0.802482    0.161294    0.398265
# 19              5.576770e+08  ...      0.823665    0.363100    0.469359
#
#     Debt to Equity  Working Capital Ratio  R&D to Revenue  Revenue growth  \
# 0         0.237102               0.337634        0.139657             NaN
# 1         0.232127               0.291860        0.147781        0.086828
# 2         0.232331               0.213100        0.140924        0.138662
# 3         0.364679               0.256415        0.151642        0.150901
# 4         0.449826               0.278906        0.303047             NaN
# 5         0.410794               0.395880        0.285266        0.156875
# 6         0.424729               0.403943        0.266704        0.219411
# 7         0.556409               0.332822        0.285481        0.221670
# 8         0.450939               0.376265        0.123629             NaN
# 9         0.428098               0.378019        0.128330        0.068820
# 10        0.660861               0.140534        0.120389        0.156700
# 11        0.548303               0.177170        0.115319        0.149322
# 12        0.421534               0.612071        0.272077             NaN
# 13        0.246951               0.553396        0.142395        1.258545
# 14        0.138522               0.475712        0.098960        1.142034
# 15        0.105664               0.432726        0.085659        0.654735
# 16        0.092268               1.287409        0.188722             NaN
# 17        0.063333               1.524756        0.181853        0.167452
# 18        0.046204               1.723350        0.177238        0.287861
# 19        0.030942               1.604889        0.124608        0.561834
#
#     Net Income Growth  EPS Growth  FCF Growth
# 0                 NaN         NaN         NaN
# 1            0.230491    0.271930    0.158057
# 2            0.356704    0.386207    0.047039
# 3            0.320142    0.344527    0.006899
# 4                 NaN         NaN         NaN
# 5            0.685259    0.731083    1.284618
# 6            0.594966    0.604573    0.227013
# 7           -0.030500         NaN   -0.147267
# 8                 NaN         NaN         NaN
# 9           -0.005183    0.003109   -0.087093
# 10           0.218004    0.219008    0.245414
# 11           0.155396    0.155932   -0.033211
# 12                NaN         NaN         NaN
# 13           5.813187    5.839080    6.095851
# 14           1.448925    1.470588    1.252063
# 15           0.647462    0.666667    0.588681
# 16                NaN         NaN         NaN
# 17          -1.561472   -1.499997    2.794399
# 18           1.202740    1.111116    0.637185
# 19           2.515941    2.310962    0.840636
#
# [20 rows x 24 columns]

# %%
print(sorted(fund_trends['ticker'].unique()))
# Out:
# ['GOOGL', 'META', 'MSFT', 'NVDA', 'PLTR']

# %% [markdown]
# Profitability trend of each company (Net Margin %)

# %%
for ticker in sorted(fund_trends['ticker'].unique()):
    ticker_data = fund_trends[fund_trends['ticker'] == ticker]
    ticker_data = ticker_data[['Date', 'Net Margin']].copy()
    ticker_data['Net Margin'] = ticker_data['Net Margin'] * 100
    ticker_data = ticker_data.sort_values('Date')
    print(len(ticker_data))
# Out:
# 4
# 4
# 4
# 4
# 4
